# %%
import os
from os import walk, getcwd
from PIL import Image

# %%
# This function helps convert the coordinates returned by Figure 8 to YOLO format
def convert(size, box):
    dw = 1./size[0]
    dh = 1./size[1]
    x = (box[0] + box[1])/2.0
    y = (box[2] + box[3])/2.0
    w = box[1] - box[0]
    h = box[3] - box[2]
    x = x*dw
    w = w*dw
    y = y*dh
    h = h*dh
    return (x,y,w,h)

# %%
print(getcwd())
#os.chdir("..")  # go back, same as cd ..
# Out:
# C:\Users\thoan\Aegis-AI\Images-Preprocessing\Sonny's Backyard in Austin, Black Pistols, June (Elevated) (labeled by Mladen-7-15-2018)

# %%
# Create new folder to store .txt files of YOLO format
if not os.path.exists("Yolo-Labels"):
    os.makedirs("Yolo-Labels")
else: 
    print("Yolo-Labels folder exist! Please check the folder first!")
# Out:
# Yolo-Labels folder exist! Please check the folder first!

# %%
# Read regular labels file names
regular_label_list = []
for (dirpath, dirnames, filenames) in walk("./Regular-Labels/"):
    #print(dirpath)
    #print(dirnames)
    print(filenames)
    regular_label_list.extend(filenames)
    break
print(regular_label_list)
print(len(regular_label_list))
# Out:
# ['2_001_2018-07-15.txt', '2_002_2018-07-15.txt', '2_003_2018-07-15.txt', '2_004_2018-07-15.txt', '2_005_2018-07-15.txt', '2_006_2018-07-15.txt', '2_007_2018-07-15.txt', '2_008_2018-07-15.txt', '2_009_2018-07-15.txt', '2_010_2018-07-15.txt', '2_011_2018-07-15.txt', '2_012_2018-07-15.txt', '2_013_2018-07-15.txt', '2_014_2018-07-15.txt', '2_015_2018-07-15.txt', '2_016_2018-07-15.txt', '2_017_2018-07-15.txt', '2_018_2018-07-15.txt', '2_019_2018-07-15.txt', '2_020_2018-07-15.txt', '2_021_2018-07-15.txt', '2_022_2018-07-15.txt', '2_023_2018-07-15.txt', '2_024_2018-07-15.txt', '2_025_2018-07-15.txt', '2_026_2018-07-15.txt']
# ['2_001_2018-07-15.txt', '2_002_2018-07-15.txt', '2_003_2018-07-15.txt', '2_004_2018-07-15.txt', '2_005_2018-07-15.txt', '2_006_2018-07-15.txt', '2_007_2018-07-15.txt', '2_008_2018-07-15.txt', '2_009_2018-07-15.txt', '2_010_2018-07-15.txt', '2_011_2018-07-15.txt', '2_012_2018-07-15.txt', '2_013_2018-07-15.txt', '2_014_2018-07-15.txt', '2_015_2018-07-15.txt', '2_016_2018-07-15.txt', '2_017_2018-07-15.txt', '2_018_2018-07-15.txt', '2_019_2018-07-15.txt', '2_020_2018-07-15.txt', '2_021_2018-07-15.txt', '2_022_2018-07-15.txt', '2_023_2018-07-15.txt', '2_024_2018-07-15.txt', '2_025_2018-07-15.txt', '2_026_2018-07-15.txt']
# 26

# %%
# Conversion process, bounding box of 392 662 660 212 will be 
# converted to (0.37604166666666666, 0.6000000000000001, 0.34375, 0.16562500000000002)
# where 1920 1280 is the size of corresponding image IMG_6339.jpg

# Input:./labels/gun_original/IMG_6339.txt
# Output:./labels/gun/IMG_6339.txt
# 392 662 660 212

# 1920 1280
# (0.37604166666666666, 0.6000000000000001, 0.34375, 0.16562500000000002)

for txt_name in regular_label_list:
    
    """ Open input text files """
    txt_path = "./Regular-Labels/" + txt_name
    print("Input: " + txt_path)
    txt_file = open(txt_path, "r")
    lines = txt_file.read().split('\n')  # or '\r\n'
    
    """ Open output text files """
    txt_outpath = "./Yolo-Labels/" + txt_name
    print("Output: " + txt_outpath)
    txt_outfile = open(txt_outpath, "w")
    
    """ Convert the data to YOLO format """
    ct = 0
    #print(lines)
    for line in lines:
        #print('lenth of line is: ')
        #print(line)
        #print('\n')
        if(len(line) >= 2):
            ct = ct + 1
            print("Regular Bounding Box: " + line)
            elems = line.split(' ')
            #print(elems)
            # Remember that elems are coordinates of x1 y1 x2 y2 where (x1, y1) is the top left corner,  
            # and (x2, y2) is the bottom right corner
            xmin = int(elems[0])
            xmax = int(elems[2])
            ymin = int(elems[1])
            ymax = int(elems[3])
            
            img_path = str('./Images/%s.JPG'%(os.path.splitext(txt_name)[0]))
            print("Image: " + img_path)

            im=Image.open(img_path)
            w= int(im.size[0])
            h= int(im.size[1])
            #w = int(xmax) - int(xmin)
            #h = int(ymax) - int(ymin)
            #print(xmin)
            print("Image's size: " + str(w) + " " + str(h))
            b = (float(xmin), float(xmax), float(ymin), float(ymax))
            #print(b)
            bb = convert((w,h), b)
            print("Yolo's coordinates: ")
            print(bb)
            print("\n")
            txt_outfile.write(str(0) + " " + " ".join([str(a) for a in bb]) + '\n')
            
    txt_outfile.close()
# Out:
# Input: ./Regular-Labels/2_001_2018-07-15.txt
# Output: ./Yolo-Labels/2_001_2018-07-15.txt
# Regular Bounding Box: 479 329 521 397
# Image: ./Images/2_001_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.48828125, 0.532258064516129, 0.041015625, 0.09970674486803519)
#
#
# Regular Bounding Box: 592 444 627 513
# Image: ./Images/2_001_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.59521484375, 0.7016129032258065, 0.0341796875, 0.10117302052785923)
#
#
# Input: ./Regular-Labels/2_002_2018-07-15.txt
# Output: ./Yolo-Labels/2_002_2018-07-15.txt
# Regular Bounding Box: 512 339 560 393
# Image: ./Images/2_002_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.5234375, 0.5366568914956011, 0.046875, 0.07917888563049853)
#
#
# Regular Bounding Box: 631 346 720 393
# Image: ./Images/2_002_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.65966796875, 0.5417888563049853, 0.0869140625, 0.0689149560117302)
#
#
# Input: ./Regular-Labels/2_003_2018-07-15.txt
# Output: ./Yolo-Labels/2_003_2018-07-15.txt
# Regular Bounding Box: 542 397 583 475
# Image: ./Images/2_003_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.54931640625, 0.6392961876832844, 0.0400390625, 0.11436950146627566)
#
#
# Regular Bounding Box: 693 46 760 197
# Image: ./Images/2_003_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.70947265625, 0.1781524926686217, 0.0654296875, 0.22140762463343108)
#
#
# Input: ./Regular-Labels/2_004_2018-07-15.txt
# Output: ./Yolo-Labels/2_004_2018-07-15.txt
# Regular Bounding Box: 532 370 572 454
# Image: ./Images/2_004_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.5390625, 0.6041055718475073, 0.0390625, 0.12316715542521994)
#
#
# Regular Bounding Box: 669 133 698 189
# Image: ./Images/2_004_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.66748046875, 0.23607038123167157, 0.0283203125, 0.08211143695014662)
#
#
# Input: ./Regular-Labels/2_005_2018-07-15.txt
# Output: ./Yolo-Labels/2_005_2018-07-15.txt
# Regular Bounding Box: 495 365 540 465
# Image: ./Images/2_005_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.50537109375, 0.6085043988269795, 0.0439453125, 0.1466275659824047)
#
#
# Regular Bounding Box: 567 413 616 491
# Image: ./Images/2_005_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.57763671875, 0.6627565982404692, 0.0478515625, 0.11436950146627566)
#
#
# Input: ./Regular-Labels/2_006_2018-07-15.txt
# Output: ./Yolo-Labels/2_006_2018-07-15.txt
# Regular Bounding Box: 694 274 806 348
# Image: ./Images/2_006_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.732421875, 0.4560117302052786, 0.109375, 0.10850439882697947)
#
#
# Regular Bounding Box: 163 5 242 111
# Image: ./Images/2_006_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.19775390625, 0.08504398826979472, 0.0771484375, 0.15542521994134897)
#
#
# Input: ./Regular-Labels/2_007_2018-07-15.txt
# Output: ./Yolo-Labels/2_007_2018-07-15.txt
# Regular Bounding Box: 576 300 632 367
# Image: ./Images/2_007_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.58984375, 0.48900293255131966, 0.0546875, 0.09824046920821114)
#
#
# Regular Bounding Box: 540 5 593 96
# Image: ./Images/2_007_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.55322265625, 0.07404692082111437, 0.0517578125, 0.13343108504398826)
#
#
# Input: ./Regular-Labels/2_008_2018-07-15.txt
# Output: ./Yolo-Labels/2_008_2018-07-15.txt
# Regular Bounding Box: 81 291 216 349
# Image: ./Images/2_008_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.14501953125, 0.46920821114369504, 0.1318359375, 0.08504398826979472)
#
#
# Regular Bounding Box: 524 495 552 565
# Image: ./Images/2_008_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.525390625, 0.7771260997067448, 0.02734375, 0.10263929618768329)
#
#
# Input: ./Regular-Labels/2_009_2018-07-15.txt
# Output: ./Yolo-Labels/2_009_2018-07-15.txt
# Regular Bounding Box: 130 231 227 279
# Image: ./Images/2_009_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.17431640625, 0.37390029325513197, 0.0947265625, 0.07038123167155425)
#
#
# Regular Bounding Box: 521 487 574 571
# Image: ./Images/2_009_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.53466796875, 0.7756598240469208, 0.0517578125, 0.12316715542521994)
#
#
# Input: ./Regular-Labels/2_010_2018-07-15.txt
# Output: ./Yolo-Labels/2_010_2018-07-15.txt
# Regular Bounding Box: 559 161 630 245
# Image: ./Images/2_010_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.58056640625, 0.29765395894428154, 0.0693359375, 0.12316715542521994)
#
#
# Regular Bounding Box: 529 480 568 563
# Image: ./Images/2_010_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.53564453125, 0.7646627565982405, 0.0380859375, 0.1217008797653959)
#
#
# Input: ./Regular-Labels/2_011_2018-07-15.txt
# Output: ./Yolo-Labels/2_011_2018-07-15.txt
# Regular Bounding Box: 505 399 539 482
# Image: ./Images/2_011_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.509765625, 0.6458944281524927, 0.033203125, 0.1217008797653959)
#
#
# Regular Bounding Box: 546 453 598 518
# Image: ./Images/2_011_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.55859375, 0.7118768328445748, 0.05078125, 0.09530791788856305)
#
#
# Input: ./Regular-Labels/2_012_2018-07-15.txt
# Output: ./Yolo-Labels/2_012_2018-07-15.txt
# Regular Bounding Box: 489 307 528 382
# Image: ./Images/2_012_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.49658203125, 0.5051319648093842, 0.0380859375, 0.10997067448680352)
#
#
# Regular Bounding Box: 565 342 616 423
# Image: ./Images/2_012_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.57666015625, 0.5608504398826979, 0.0498046875, 0.1187683284457478)
#
#
# Input: ./Regular-Labels/2_013_2018-07-15.txt
# Output: ./Yolo-Labels/2_013_2018-07-15.txt
# Regular Bounding Box: 459 346 498 438
# Image: ./Images/2_013_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.46728515625, 0.5747800586510264, 0.0380859375, 0.1348973607038123)
#
#
# Regular Bounding Box: 563 99 612 213
# Image: ./Images/2_013_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.57373046875, 0.2287390029325513, 0.0478515625, 0.16715542521994134)
#
#
# Input: ./Regular-Labels/2_014_2018-07-15.txt
# Output: ./Yolo-Labels/2_014_2018-07-15.txt
# Regular Bounding Box: 441 404 515 499
# Image: ./Images/2_014_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.466796875, 0.6620234604105572, 0.072265625, 0.13929618768328444)
#
#
# Regular Bounding Box: 576 73 609 201
# Image: ./Images/2_014_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.57861328125, 0.20087976539589442, 0.0322265625, 0.187683284457478)
#
#
# Input: ./Regular-Labels/2_015_2018-07-15.txt
# Output: ./Yolo-Labels/2_015_2018-07-15.txt
# Regular Bounding Box: 397 430 512 506
# Image: ./Images/2_015_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.44384765625, 0.6862170087976539, 0.1123046875, 0.11143695014662756)
#
#
# Regular Bounding Box: 624 72 674 209
# Image: ./Images/2_015_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.6337890625, 0.2060117302052786, 0.048828125, 0.20087976539589442)
#
#
# Input: ./Regular-Labels/2_016_2018-07-15.txt
# Output: ./Yolo-Labels/2_016_2018-07-15.txt
# Regular Bounding Box: 409 428 528 483
# Image: ./Images/2_016_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.45751953125, 0.6678885630498533, 0.1162109375, 0.08064516129032258)
#
#
# Regular Bounding Box: 558 103 618 234
# Image: ./Images/2_016_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.57421875, 0.2470674486803519, 0.05859375, 0.19208211143695014)
#
#
# Input: ./Regular-Labels/2_017_2018-07-15.txt
# Output: ./Yolo-Labels/2_017_2018-07-15.txt
# Regular Bounding Box: 520 118 559 224
# Image: ./Images/2_017_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.52685546875, 0.250733137829912, 0.0380859375, 0.15542521994134897)
#
#
# Regular Bounding Box: 610 351 700 442
# Image: ./Images/2_017_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.6396484375, 0.5813782991202346, 0.087890625, 0.13343108504398826)
#
#
# Input: ./Regular-Labels/2_018_2018-07-15.txt
# Output: ./Yolo-Labels/2_018_2018-07-15.txt
# Regular Bounding Box: 564 124 590 222
# Image: ./Images/2_018_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.5634765625, 0.2536656891495601, 0.025390625, 0.1436950146627566)
#
#
# Regular Bounding Box: 708 279 776 397
# Image: ./Images/2_018_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.724609375, 0.49560117302052786, 0.06640625, 0.17302052785923755)
#
#
# Input: ./Regular-Labels/2_019_2018-07-15.txt
# Output: ./Yolo-Labels/2_019_2018-07-15.txt
# Regular Bounding Box: 696 457 758 533
# Image: ./Images/2_019_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.7099609375, 0.7258064516129032, 0.060546875, 0.11143695014662756)
#
#
# Regular Bounding Box: 542 90 575 180
# Image: ./Images/2_019_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.54541015625, 0.19794721407624633, 0.0322265625, 0.13196480938416422)
#
#
# Input: ./Regular-Labels/2_020_2018-07-15.txt
# Output: ./Yolo-Labels/2_020_2018-07-15.txt
# Regular Bounding Box: 504 43 527 110
# Image: ./Images/2_020_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.50341796875, 0.11217008797653959, 0.0224609375, 0.09824046920821114)
#
#
# Regular Bounding Box: 392 399 500 461
# Image: ./Images/2_020_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.435546875, 0.6304985337243402, 0.10546875, 0.09090909090909091)
#
#
# Input: ./Regular-Labels/2_021_2018-07-15.txt
# Output: ./Yolo-Labels/2_021_2018-07-15.txt
# Regular Bounding Box: 655 173 689 220
# Image: ./Images/2_021_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.65625, 0.28812316715542524, 0.033203125, 0.0689149560117302)
#
#
# Regular Bounding Box: 463 97 488 154
# Image: ./Images/2_021_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.46435546875, 0.1840175953079179, 0.0244140625, 0.08357771260997067)
#
#
# Input: ./Regular-Labels/2_022_2018-07-15.txt
# Output: ./Yolo-Labels/2_022_2018-07-15.txt
# Regular Bounding Box: 439 484 491 585
# Image: ./Images/2_022_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.4541015625, 0.783724340175953, 0.05078125, 0.14809384164222875)
#
#
# Regular Bounding Box: 485 404 555 478
# Image: ./Images/2_022_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.5078125, 0.6466275659824047, 0.068359375, 0.10850439882697947)
#
#
# Input: ./Regular-Labels/2_023_2018-07-15.txt
# Output: ./Yolo-Labels/2_023_2018-07-15.txt
# Regular Bounding Box: 165 275 308 362
# Image: ./Images/2_023_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.23095703125, 0.4670087976539589, 0.1396484375, 0.12756598240469208)
#
#
# Regular Bounding Box: 548 477 615 571
# Image: ./Images/2_023_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.56787109375, 0.7683284457478006, 0.0654296875, 0.1378299120234604)
#
#
# Input: ./Regular-Labels/2_024_2018-07-15.txt
# Output: ./Yolo-Labels/2_024_2018-07-15.txt
# Regular Bounding Box: 441 75 505 219
# Image: ./Images/2_024_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.4619140625, 0.2155425219941349, 0.0625, 0.21114369501466276)
#
#
# Regular Bounding Box: 576 207 654 326
# Image: ./Images/2_024_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.6005859375, 0.3907624633431085, 0.076171875, 0.1744868035190616)
#
#
# Input: ./Regular-Labels/2_025_2018-07-15.txt
# Output: ./Yolo-Labels/2_025_2018-07-15.txt
# Regular Bounding Box: 569 404 673 445
# Image: ./Images/2_025_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.6064453125, 0.6224340175953079, 0.1015625, 0.060117302052785926)
#
#
# Regular Bounding Box: 585 335 673 380
# Image: ./Images/2_025_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.6142578125, 0.5241935483870968, 0.0859375, 0.06598240469208211)
#
#
# Input: ./Regular-Labels/2_026_2018-07-15.txt
# Output: ./Yolo-Labels/2_026_2018-07-15.txt
# Regular Bounding Box: 208 375 330 429
# Image: ./Images/2_026_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.2626953125, 0.5894428152492669, 0.119140625, 0.07917888563049853)
#
#
# Regular Bounding Box: 284 275 382 346
# Image: ./Images/2_026_2018-07-15.JPG
# Image's size: 1024 682
# Yolo's coordinates:
# (0.3251953125, 0.45527859237536655, 0.095703125, 0.10410557184750734)

# %%
# !jupyter nbconvert --to script convert_to_Yolo_format.ipynb
# Out:
# [NbConvertApp] Converting notebook convert_to_Yolo_format.ipynb to script
# [NbConvertApp] Writing 3310 bytes to convert_to_Yolo_format.py
