# %% [markdown]
# # 2018 FIFA World Cup Predictions!
#
# In this notebook, we are going to develop machine learning models to predict World Cup 2018's outcomes!
#
# The datasets are obtained from Kaggle (link ...). We are going to perform some exploratory analysis, then feature engineering, then data manipulation, choose the best model, and then deploy on the datasets.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.ticker as plticker
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ## Read the datasets into dataframes
# world_cup contains information about the participating teams in the tournament.
# results contains records of all matches since the beginning of World Cup.

# %%
#load data 
world_cup = pd.read_csv('datasets/World Cup 2018 Dataset.csv')
results = pd.read_csv('datasets/results.csv')

# %% [markdown]
# world_cup dataframe consists of 33 rows (32 teams and 1 header) and 20 columns

# %%
world_cup.shape
# Out:
# (33, 20)

# %%
world_cup.head()
# Out:
#            Team Group  Previous \r\nappearances  Previous \r\ntitles  \
# 0        Russia     A                      10.0                  0.0
# 1  Saudi Arabia     A                       4.0                  0.0
# 2         Egypt     A                       2.0                  0.0
# 3       Uruguay     A                      12.0                  2.0
# 4       Porugal     B                       6.0                  0.0
#
#    Previous\r\n finals  Previous\r\n semifinals  Current \r\nFIFA rank  \
# 0                  0.0                      1.0                   65.0
# 1                  0.0                      0.0                   63.0
# 2                  0.0                      0.0                   31.0
# 3                  2.0                      5.0                   21.0
# 4                  0.0                      2.0                    3.0
#
#   First match \r\nagainst  Match index  \
# 0            Saudi Arabia          1.0
# 1                  Russia          1.0
# 2                 Uruguay          2.0
# 3                   Egypt          2.0
# 4                   Spain          3.0
#
#    history with \r\nfirst opponent\r\n W-L  \
# 0                                     -1.0
# 1                                      1.0
# 2                                     -1.0
# 3                                      1.0
# 4                                    -12.0
#
#    history with\r\n first opponent\r\n goals Second match\r\n against  \
# 0                                       -2.0                    Egypt
# 1                                        2.0                  Uruguay
# 2                                       -2.0                   Russia
# 3                                        2.0             Saudi Arabia
# 4                                      -31.0                  Morocco
#
#    Match index.1  history with\r\n second opponent\r\n W-L  \
# 0           17.0                                       NaN
# 1           18.0                                       1.0
# 2           17.0                                       NaN
# 3           18.0                                      -1.0
# 4           19.0                                      -1.0
#
#    history with\r\n second opponent\r\n goals Third match\r\n against  \
# 0                                         NaN                 Uruguay
# 1                                         1.0                   Egypt
# 2                                         NaN            Saudi Arabia
# 3                                        -1.0                  Russia
# 4                                        -2.0                    Iran
#
#    Match index.2  history with\r\n third opponent\r\n W-L  \
# 0           33.0                                      0.0
# 1           34.0                                     -5.0
# 2           34.0                                      5.0
# 3           33.0                                      0.0
# 4           35.0                                      2.0
#
#    history with\r\n third opponent\r\n goals  Unnamed: 19
# 0                                        0.0          NaN
# 1                                       -5.0          NaN
# 2                                        5.0          NaN
# 3                                        0.0          NaN
# 4                                        5.0          NaN

# %% [markdown]
# results consists of 38902 rows (representing all the international matches) and 8 columns.

# %%
results.shape
# Out:
# (38902, 8)

# %%
results.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country
# 0  Scotland
# 1   England
# 2  Scotland
# 3   England
# 4  Scotland

# %% [markdown]
# ## Exploratory Analysis
# We will need to combine the two datasets for our predictions. For example, "Current FIFA rank" in world_cup dataframe will play an important role in predicting future outcomes. Meanwhile, 'results' dataframe will provide insight about all the matches for one particular team, say team A, as well as its performance against some particular team B.

# %%
# adding new columns for data analysis, in this case the winner and goal difference of a game
winner = []
for i in range (len(results['home_team'])):
    if results ['home_score'][i] > results['away_score'][i]:
        winner.append(results['home_team'][i])
    elif results['home_score'][i] < results ['away_score'][i]:
        winner.append(results['away_team'][i])
    else:
        winner.append('Tie')
# adding 'winning_team' column to 'results' dataframe        
results['winning_team'] = winner

# adding 'goal_difference' column to 'results' dataframe
results['goal_difference'] = np.absolute(results['home_score'] - results['away_score'])

results.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country winning_team  goal_difference
# 0  Scotland          Tie                0
# 1   England      England                2
# 2  Scotland     Scotland                1
# 3   England          Tie                0
# 4  Scotland     Scotland                3

# %% [markdown]
# We can start to think which factors we should focus on and which ones we should ignore.
# Does city play any important role? Most likely no. How about country? Yes if one team gets to play at its home country (But for World Cup all teams will play at some other host country, so I would get rid of 'country' as well).
#
# We notice that there's "Friendly" in 'tournament'. From this we can start to think if 'tournament' is going to play any important role in the predictions? Personally, I think that many teams do not tend to play seriously in a "Friendly" tournament. So I might consider getting rid of all "Friendly" matches in later steps.

# %%
tournament = results['tournament'].unique()
print(list(tournament))
# Out:
# ['Friendly', 'British Championship', 'Copa Lipton', 'Copa Newton', 'Copa Premio Honor Argentino', 'Copa Premio Honor Uruguayo', 'Copa Roca', 'Copa América', 'Copa Chevallier Boutell', 'Nordic Championship', 'International Cup', 'Baltic Cup', 'Balkan Cup', 'FIFA World Cup', 'Copa Rio Branco', 'FIFA World Cup qualification', 'CCCF Championship', 'NAFU Championship', 'Copa Oswaldo Cruz', 'Pan American Championship', 'Copa del Pacífico', "Copa Bernardo O'Higgins", 'AFC Asian Cup qualification', 'Atlantic Cup', 'AFC Asian Cup', 'African Cup of Nations', 'Copa Paz del Chaco', 'Merdeka Tournament', 'UEFA Euro qualification', 'UEFA Euro', 'Windward Islands Tournament', 'African Cup of Nations qualification', 'Vietnam Independence Cup', 'Copa Carlos Dittborn', 'CONCACAF Championship', 'Copa Juan Pinto Durán', 'UAFA Cup', 'South Pacific Games', 'CONCACAF Championship qualification', 'Copa Artigas', 'GaNEFo', "King's Cup", 'Gulf Cup', 'Indonesia Tournament', 'Korea Cup', 'Brazil Independence Cup', 'Copa Ramón Castilla', 'Oceania Nations Cup', 'CECAFA Cup', 'Copa Félix Bogado', 'Kirin Cup', 'CFU Caribbean Cup qualification', 'CFU Caribbean Cup', 'Amílcar Cabral Cup', 'Mundialito', 'West African Cup', 'Nehru Cup', 'Merlion Cup', 'UDEAC Cup', 'Rous Cup', 'Lunar New Year Cup', 'Tournoi de France', 'Malta International Tournament', 'Dynasty Cup', 'UNCAF Cup', 'Gold Cup', 'USA Cup', 'Jordan International Tournament', 'Confederations Cup', 'United Arab Emirates Friendship Tournament', 'Oceania Nations Cup qualification', 'Simba Tnmt.', 'SAFF Cup', 'AFF Championship', 'King Hassan II Tournament', 'Cyprus International Tournament', 'Dunhill Cup', 'COSAFA Cup', 'Gold Cup qualification', 'SKN Football Festival', 'UNIFFAC Cup', 'WAFF Championship', 'Millennium Cup', "Prime Minister's Cup", 'EAFF Championship', 'AFC Challenge Cup', 'UAFA Cup qualification', 'AFC Challenge Cup qualification', 'African Nations Championship', 'VFF Cup', 'Dragon Cup', 'ABCS Tournament', 'Nile Basin Tnmt.', 'Nations Cup', 'OSN Cup']

# %% [markdown]
# How many teams are there in the 'results' data set? 245

# %%
home_team_total = list(results['home_team'].unique())
away_team_total = list(results['away_team'].unique())
team_total = list(set(home_team_total + away_team_total))
team_total.sort()
len(team_total)
# Out:
# 245

# %% [markdown]
# How many teams have played in World Cup since the beginning? 79

# %%
df_world_cup = results[results['tournament'] == 'FIFA World Cup']
home_team_world_cup = list(df_world_cup['home_team'].unique())
away_team_world_cup = list(df_world_cup['away_team'].unique())
world_cup_team_total = list(set(home_team_world_cup + away_team_world_cup))
print(len(world_cup_team_total))
print(world_cup_team_total)
# Out:
# 79
# ['Denmark', 'Yugoslavia', 'South Africa', 'Russia', 'Hungary', 'Congo DR', 'Colombia', 'Australia', 'Bolivia', 'United Arab Emirates', 'El Salvador', 'Honduras', 'Iran', 'Poland', 'Iraq', 'Saudi Arabia', 'Germany', 'Serbia', 'Senegal', 'Spain', 'Italy', 'Ghana', 'Sweden', 'Norway', 'German DR', 'Ecuador', 'Wales', 'Kuwait', 'Ukraine', 'Turkey', 'China', 'Cameroon', 'New Zealand', 'Canada', 'USA', 'Japan', 'Romania', 'Korea Republic', 'Algeria', 'Morocco', 'Croatia', 'Tunisia', 'Costa Rica', 'Slovakia', 'Brazil', 'Chile', 'Togo', 'Korea DPR', 'France', 'Mexico', 'Indonesia', 'Cuba', 'Belgium', 'Switzerland', 'Angola', 'Ireland', 'Netherlands', 'Portugal', 'Jamaica', 'Bosnia-Herzegovina', 'Czechoslovakia', 'Egypt', 'Haiti', 'England', 'Slovenia', 'Trinidad and Tobago', 'Argentina', 'Bulgaria', 'Ivory Coast', 'Greece', 'Paraguay', 'Peru', 'Nigeria', 'Northern Ireland', 'Austria', 'Israel', 'Uruguay', 'Scotland', 'Czech Republic']

# %% [markdown]
# Let's play around with the data by focusing on one of my favorite team, say Argentina.

# %%
# slice the dataset to create the 'argentina' dataframe
df = results[(results['home_team'] == 'Argentina') | (results['away_team'] == 'Argentina')]
argentina = df.iloc[:]
argentina.head()
# Out:
#            date  home_team  away_team  home_score  away_score   tournament  \
# 144  1902-07-20    Uruguay  Argentina           0           6     Friendly
# 152  1903-09-13  Argentina    Uruguay           2           3     Friendly
# 173  1905-08-15  Argentina    Uruguay           0           0  Copa Lipton
# 184  1906-08-15    Uruguay  Argentina           0           2  Copa Lipton
# 186  1906-10-21  Argentina    Uruguay           2           1  Copa Newton
#
#              city    country winning_team  goal_difference
# 144    Montevideo    Uruguay    Argentina                6
# 152  Buenos Aires  Argentina      Uruguay                1
# 173  Buenos Aires  Argentina          Tie                0
# 184    Montevideo    Uruguay    Argentina                2
# 186  Buenos Aires  Argentina    Argentina                1

# %% [markdown]
# Extract all matches after 1930 of the data, since we only care about matches since the 1st World Cup, which is 1930.

# %%
# adding a column for year and the first world cup was held in 1930
year = []
# getting the year out of each date
for row in argentina['date']:
    year.append(int(row[:4]))
    
argentina['match_year']= year

argentina_1930 = argentina[argentina['match_year'] >= 1930]
argentina_1930.count()
# Out:
# date               800
# home_team          800
# away_team          800
# home_score         800
# away_score         800
# tournament         800
# city               800
# country            800
# winning_team       800
# goal_difference    800
# match_year         800
# dtype: int64

# %% [markdown]
# So Argentina has played in total 800 international matches since 1930. Let's visualize their results!

# %%
# (histogram) visualization of win-tie-loss games for argentina

winning_rate = []
for row in argentina_1930['winning_team']:
    if row != 'Argentina' and row != 'Tie':
        winning_rate.append('Loss')
    else:
        winning_rate.append(row)
winning_df= pd.DataFrame(winning_rate, columns=[ 'Argentina_Results'])

# plotting using seaborn
fig, ax = plt.subplots(1,2)
fig.set_size_inches(15, 6)
sns.set(style='darkgrid')
sns.countplot(x='Argentina_Results', data=winning_df, ax=ax[0])
sns.countplot(x='match_year', data=argentina_1930, ax=ax[1])
plt.xticks(np.arange(min(argentina_1930.match_year), max(argentina_1930.match_year), 100))
# Out:
# ([<matplotlib.axis.XTick at 0x2165d0b86a0>],
#  <a list of 1 Text xticklabel objects>)

# %%
argentina_1930.groupby('match_year').count()
# Out:
#             date  home_team  away_team  home_score  away_score  tournament  \
# match_year
# 1930           7          7          7           7           7           7
# 1931           4          4          4           4           4           4
# 1932           2          2          2           2           2           2
# 1933           3          3          3           3           3           3
# 1934           3          3          3           3           3           3
# 1935           5          5          5           5           5           5
# 1936           3          3          3           3           3           3
# 1937           7          7          7           7           7           7
# 1938           2          2          2           2           2           2
# 1939           4          4          4           4           4           4
# 1940          11         11         11          11          11          11
# 1941           9          9          9           9           9           9
# 1942           8          8          8           8           8           8
# 1943           4          4          4           4           4           4
# 1945          15         15         15          15          15          15
# 1946           5          5          5           5           5           5
# 1947           7          7          7           7           7           7
# 1950           2          2          2           2           2           2
# 1951           2          2          2           2           2           2
# 1952           2          2          2           2           2           2
# 1953           3          3          3           3           3           3
# 1954           2          2          2           2           2           2
# 1955           5          5          5           5           5           5
# 1956          17         17         17          17          17          17
# 1957          15         15         15          15          15          15
# 1958           7          7          7           7           7           7
# 1959          11         11         11          11          11          11
# 1960          14         14         14          14          14          14
# 1961           8          8          8           8           8           8
# 1962           8          8          8           8           8           8
# 1963          10         10         10          10          10          10
# 1964           7          7          7           7           7           7
# 1965           9          9          9           9           9           9
# 1966           6          6          6           6           6           6
# 1967           9          9          9           9           9           9
# 1968          11         11         11          11          11          11
# 1969           8          8          8           8           8           8
# 1970           5          5          5           5           5           5
# 1971          10         10         10          10          10          10
# 1972          10         10         10          10          10          10
# 1973          12         12         12          12          12          12
# 1974          13         13         13          13          13          13
# 1975           8          8          8           8           8           8
# 1976          13         13         13          13          13          13
# 1977          11         11         11          11          11          11
# 1978          13         13         13          13          13          13
# 1979          11         11         11          11          11          11
# 1980           9          9          9           9           9           9
# 1981           4          4          4           4           4           4
# 1982          10         10         10          10          10          10
# 1983           8          8          8           8           8           8
# 1984          12         12         12          12          12          12
# 1985          12         12         12          12          12          12
# 1986           9          9          9           9           9           9
# 1987           7          7          7           7           7           7
# 1988           7          7          7           7           7           7
# 1989          11         11         11          11          11          11
# 1990          12         12         12          12          12          12
# 1991          14         14         14          14          14          14
# 1992           6          6          6           6           6           6
# 1993          17         17         17          17          17          17
# 1994          12         12         12          12          12          12
# 1995          16         16         16          16          16          16
# 1996           7          7          7           7           7           7
# 1997          14         14         14          14          14          14
# 1998          13         13         13          13          13          13
# 1999          14         14         14          14          14          14
# 2000          12         12         12          12          12          12
# 2001           9          9          9           9           9           9
# 2002           7          7          7           7           7           7
# 2003          13         13         13          13          13          13
# 2004          17         17         17          17          17          17
# 2005          17         17         17          17          17          17
# 2006           9          9          9           9           9           9
# 2007          16         16         16          16          16          16
# 2008          10         10         10          10          10          10
# 2009          11         11         11          11          11          11
# 2010          14         14         14          14          14          14
# 2011          21         21         21          21          21          21
# 2012          11         11         11          11          11          11
# 2013          12         12         12          12          12          12
# 2014          15         15         15          15          15          15
# 2015           8          8          8           8           8           8
# 2016          11         11         11          11          11          11
# 2017          10         10         10          10          10          10
# 2018           2          2          2           2           2           2
#
#             city  country  winning_team  goal_difference
# match_year
# 1930           7        7             7                7
# 1931           4        4             4                4
# 1932           2        2             2                2
# 1933           3        3             3                3
# 1934           3        3             3                3
# 1935           5        5             5                5
# 1936           3        3             3                3
# 1937           7        7             7                7
# 1938           2        2             2                2
# 1939           4        4             4                4
# 1940          11       11            11               11
# 1941           9        9             9                9
# 1942           8        8             8                8
# 1943           4        4             4                4
# 1945          15       15            15               15
# 1946           5        5             5                5
# 1947           7        7             7                7
# 1950           2        2             2                2
# 1951           2        2             2                2
# 1952           2        2             2                2
# 1953           3        3             3                3
# 1954           2        2             2                2
# 1955           5        5             5                5
# 1956          17       17            17               17
# 1957          15       15            15               15
# 1958           7        7             7                7
# 1959          11       11            11               11
# 1960          14       14            14               14
# 1961           8        8             8                8
# 1962           8        8             8                8
# 1963          10       10            10               10
# 1964           7        7             7                7
# 1965           9        9             9                9
# 1966           6        6             6                6
# 1967           9        9             9                9
# 1968          11       11            11               11
# 1969           8        8             8                8
# 1970           5        5             5                5
# 1971          10       10            10               10
# 1972          10       10            10               10
# 1973          12       12            12               12
# 1974          13       13            13               13
# 1975           8        8             8                8
# 1976          13       13            13               13
# 1977          11       11            11               11
# 1978          13       13            13               13
# 1979          11       11            11               11
# 1980           9        9             9                9
# 1981           4        4             4                4
# 1982          10       10            10               10
# 1983           8        8             8                8
# 1984          12       12            12               12
# 1985          12       12            12               12
# 1986           9        9             9                9
# 1987           7        7             7                7
# 1988           7        7             7                7
# 1989          11       11            11               11
# 1990          12       12            12               12
# 1991          14       14            14               14
# 1992           6        6             6                6
# 1993          17       17            17               17
# 1994          12       12            12               12
# 1995          16       16            16               16
# 1996           7        7             7                7
# 1997          14       14            14               14
# 1998          13       13            13               13
# 1999          14       14            14               14
# 2000          12       12            12               12
# 2001           9        9             9                9
# 2002           7        7             7                7
# 2003          13       13            13               13
# 2004          17       17            17               17
# 2005          17       17            17               17
# 2006           9        9             9                9
# 2007          16       16            16               16
# 2008          10       10            10               10
# 2009          11       11            11               11
# 2010          14       14            14               14
# 2011          21       21            21               21
# 2012          11       11            11               11
# 2013          12       12            12               12
# 2014          15       15            15               15
# 2015           8        8             8                8
# 2016          11       11            11               11
# 2017          10       10            10               10
# 2018           2        2             2                2

# %% [markdown]
# What if we want to narrow down our focus on all World Cup games of Argentina since 1930?

# %%
argentina_1930_world_cup = argentina_1930[argentina_1930['tournament'] == 'FIFA World Cup']
argentina_1930_world_cup
# Out:
#              date    home_team           away_team  home_score  away_score  \
# 1281   1930-07-15    Argentina              France           1           0
# 1287   1930-07-19    Argentina              Mexico           6           3
# 1292   1930-07-22    Argentina               Chile           3           1
# 1294   1930-07-26    Argentina                 USA           6           1
# 1296   1930-07-30      Uruguay           Argentina           4           2
# 1649   1934-05-27    Argentina              Sweden           2           3
# 4295   1958-06-08    Argentina             Germany           1           3
# 4303   1958-06-11    Argentina    Northern Ireland           3           1
# 4311   1958-06-15    Argentina      Czechoslovakia           1           6
# 5062   1962-05-30    Argentina            Bulgaria           1           0
# 5070   1962-06-02    Argentina             England           1           3
# 5081   1962-06-06    Argentina             Hungary           0           0
# 6143   1966-07-13    Argentina               Spain           2           1
# 6151   1966-07-16    Argentina             Germany           0           0
# 6156   1966-07-19    Argentina         Switzerland           2           0
# 6165   1966-07-23      England           Argentina           1           0
# 8945   1974-06-15       Poland           Argentina           3           2
# 8952   1974-06-19    Argentina               Italy           1           1
# 8960   1974-06-23    Argentina               Haiti           4           1
# 8966   1974-06-26  Netherlands           Argentina           4           0
# 8969   1974-06-30    Argentina              Brazil           1           2
# 8973   1974-07-03    Argentina           German DR           1           1
# 10424  1978-06-02    Argentina             Hungary           2           1
# 10431  1978-06-06    Argentina              France           2           1
# 10439  1978-06-10    Argentina               Italy           0           1
# 10450  1978-06-14    Argentina              Poland           2           0
# 10458  1978-06-18    Argentina              Brazil           0           0
# 10463  1978-06-21    Argentina                Peru           6           0
# 10472  1978-06-25    Argentina         Netherlands           3           1
# 12170  1982-06-13    Argentina             Belgium           0           1
# 12185  1982-06-18    Argentina             Hungary           4           1
# 12201  1982-06-23    Argentina         El Salvador           2           0
# 12216  1982-06-29        Italy           Argentina           2           1
# 12219  1982-07-02    Argentina              Brazil           1           3
# 14101  1986-06-02    Argentina      Korea Republic           3           1
# 14114  1986-06-05        Italy           Argentina           1           1
# 14129  1986-06-10    Argentina            Bulgaria           2           0
# 14143  1986-06-16    Argentina             Uruguay           1           0
# 14152  1986-06-22    Argentina             England           2           1
# 14155  1986-06-25    Argentina             Belgium           2           0
# 14158  1986-06-29    Argentina             Germany           3           2
# 15985  1990-06-08    Argentina            Cameroon           0           1
# 15997  1990-06-13    Argentina              Russia           2           0
# 16010  1990-06-18    Argentina             Romania           1           1
# 16024  1990-06-24       Brazil           Argentina           0           1
# 16031  1990-06-30   Yugoslavia           Argentina           0           0
# 16034  1990-07-03        Italy           Argentina           1           1
# 16038  1990-07-08      Germany           Argentina           1           0
# 18239  1994-06-21    Argentina              Greece           4           0
# 18249  1994-06-25    Argentina             Nigeria           2           1
# 18264  1994-06-30    Argentina            Bulgaria           0           2
# 18270  1994-07-03      Romania           Argentina           3           2
# 21135  1998-06-14    Argentina               Japan           1           0
# 21152  1998-06-21    Argentina             Jamaica           5           0
# 21172  1998-06-26    Argentina             Croatia           1           0
# 21187  1998-06-30    Argentina             England           2           2
# 21193  1998-07-04  Netherlands           Argentina           2           1
# 24532  2002-06-02    Argentina             Nigeria           1           0
# 24550  2002-06-07    Argentina             England           0           1
# 24571  2002-06-12       Sweden           Argentina           1           1
# 28023  2006-06-10    Argentina         Ivory Coast           2           1
# 28041  2006-06-16    Argentina              Serbia           6           0
# 28059  2006-06-21  Netherlands           Argentina           0           0
# 28069  2006-06-24    Argentina              Mexico           2           1
# 28083  2006-06-30      Germany           Argentina           1           1
# 31668  2010-06-12    Argentina             Nigeria           1           0
# 31683  2010-06-17    Argentina      Korea Republic           4           1
# 31705  2010-06-22       Greece           Argentina           0           2
# 31723  2010-06-27    Argentina              Mexico           3           1
# 31733  2010-07-03    Argentina             Germany           0           4
# 35534  2014-06-15    Argentina  Bosnia-Herzegovina           2           1
# 35553  2014-06-21    Argentina                Iran           1           0
# 35573  2014-06-25      Nigeria           Argentina           2           3
# 35585  2014-07-01    Argentina         Switzerland           1           0
# 35590  2014-07-05    Argentina             Belgium           1           0
# 35594  2014-07-09  Netherlands           Argentina           0           0
# 35598  2014-07-13      Germany           Argentina           1           0
#
#            tournament               city       country    winning_team  \
# 1281   FIFA World Cup         Montevideo       Uruguay       Argentina
# 1287   FIFA World Cup         Montevideo       Uruguay       Argentina
# 1292   FIFA World Cup         Montevideo       Uruguay       Argentina
# 1294   FIFA World Cup         Montevideo       Uruguay       Argentina
# 1296   FIFA World Cup         Montevideo       Uruguay         Uruguay
# 1649   FIFA World Cup            Bologna         Italy          Sweden
# 4295   FIFA World Cup              Malmö        Sweden         Germany
# 4303   FIFA World Cup           Halmstad        Sweden       Argentina
# 4311   FIFA World Cup        Helsingborg        Sweden  Czechoslovakia
# 5062   FIFA World Cup           Rancagua         Chile       Argentina
# 5070   FIFA World Cup           Rancagua         Chile         England
# 5081   FIFA World Cup           Rancagua         Chile             Tie
# 6143   FIFA World Cup         Birmingham       England       Argentina
# 6151   FIFA World Cup         Birmingham       England             Tie
# 6156   FIFA World Cup          Sheffield       England       Argentina
# 6165   FIFA World Cup             London       England         England
# 8945   FIFA World Cup          Stuttgart       Germany          Poland
# 8952   FIFA World Cup          Stuttgart       Germany             Tie
# 8960   FIFA World Cup             Munich       Germany       Argentina
# 8966   FIFA World Cup      Gelsenkirchen       Germany     Netherlands
# 8969   FIFA World Cup            Hanover       Germany          Brazil
# 8973   FIFA World Cup      Gelsenkirchen       Germany             Tie
# 10424  FIFA World Cup       Buenos Aires     Argentina       Argentina
# 10431  FIFA World Cup       Buenos Aires     Argentina       Argentina
# 10439  FIFA World Cup       Buenos Aires     Argentina           Italy
# 10450  FIFA World Cup            Rosario     Argentina       Argentina
# 10458  FIFA World Cup            Rosario     Argentina             Tie
# 10463  FIFA World Cup            Rosario     Argentina       Argentina
# 10472  FIFA World Cup       Buenos Aires     Argentina       Argentina
# 12170  FIFA World Cup          Barcelona         Spain         Belgium
# 12185  FIFA World Cup           Alicante         Spain       Argentina
# 12201  FIFA World Cup           Alicante         Spain       Argentina
# 12216  FIFA World Cup          Barcelona         Spain           Italy
# 12219  FIFA World Cup          Barcelona         Spain          Brazil
# 14101  FIFA World Cup        Mexico City        Mexico       Argentina
# 14114  FIFA World Cup             Puebla        Mexico             Tie
# 14129  FIFA World Cup        Mexico City        Mexico       Argentina
# 14143  FIFA World Cup             Puebla        Mexico       Argentina
# 14152  FIFA World Cup        Mexico City        Mexico       Argentina
# 14155  FIFA World Cup        Mexico City        Mexico       Argentina
# 14158  FIFA World Cup        Mexico City        Mexico       Argentina
# 15985  FIFA World Cup              Milan         Italy        Cameroon
# 15997  FIFA World Cup             Naples         Italy       Argentina
# 16010  FIFA World Cup             Naples         Italy             Tie
# 16024  FIFA World Cup              Turin         Italy       Argentina
# 16031  FIFA World Cup           Florence         Italy             Tie
# 16034  FIFA World Cup             Naples         Italy             Tie
# 16038  FIFA World Cup               Rome         Italy         Germany
# 18239  FIFA World Cup         Foxborough           USA       Argentina
# 18249  FIFA World Cup         Foxborough           USA       Argentina
# 18264  FIFA World Cup             Dallas           USA        Bulgaria
# 18270  FIFA World Cup           Pasadena           USA         Romania
# 21135  FIFA World Cup           Toulouse        France       Argentina
# 21152  FIFA World Cup              Paris        France       Argentina
# 21172  FIFA World Cup           Bordeaux        France       Argentina
# 21187  FIFA World Cup      Saint-Étienne        France             Tie
# 21193  FIFA World Cup         Marseilles        France     Netherlands
# 24532  FIFA World Cup            Kashima         Japan       Argentina
# 24550  FIFA World Cup            Sapporo         Japan         England
# 24571  FIFA World Cup               Rifu         Japan             Tie
# 28023  FIFA World Cup            Hamburg       Germany       Argentina
# 28041  FIFA World Cup      Gelsenkirchen       Germany       Argentina
# 28059  FIFA World Cup  Frankfurt am Main       Germany             Tie
# 28069  FIFA World Cup            Leipzig       Germany       Argentina
# 28083  FIFA World Cup             Berlin       Germany             Tie
# 31668  FIFA World Cup       Johannesburg  South Africa       Argentina
# 31683  FIFA World Cup       Johannesburg  South Africa       Argentina
# 31705  FIFA World Cup          Polokwane  South Africa       Argentina
# 31723  FIFA World Cup       Johannesburg  South Africa       Argentina
# 31733  FIFA World Cup          Cape Town  South Africa         Germany
# 35534  FIFA World Cup     Rio de Janeiro        Brazil       Argentina
# 35553  FIFA World Cup     Belo Horizonte        Brazil       Argentina
# 35573  FIFA World Cup       Porto Alegre        Brazil       Argentina
# 35585  FIFA World Cup          São Paulo        Brazil       Argentina
# 35590  FIFA World Cup           Brasília        Brazil       Argentina
# 35594  FIFA World Cup          São Paulo        Brazil             Tie
# 35598  FIFA World Cup     Rio de Janeiro        Brazil         Germany
#
#        goal_difference  match_year
# 1281                 1        1930
# 1287                 3        1930
# 1292                 2        1930
# 1294                 5        1930
# 1296                 2        1930
# 1649                 1        1934
# 4295                 2        1958
# 4303                 2        1958
# 4311                 5        1958
# 5062                 1        1962
# 5070                 2        1962
# 5081                 0        1962
# 6143                 1        1966
# 6151                 0        1966
# 6156                 2        1966
# 6165                 1        1966
# 8945                 1        1974
# 8952                 0        1974
# 8960                 3        1974
# 8966                 4        1974
# 8969                 1        1974
# 8973                 0        1974
# 10424                1        1978
# 10431                1        1978
# 10439                1        1978
# 10450                2        1978
# 10458                0        1978
# 10463                6        1978
# 10472                2        1978
# 12170                1        1982
# 12185                3        1982
# 12201                2        1982
# 12216                1        1982
# 12219                2        1982
# 14101                2        1986
# 14114                0        1986
# 14129                2        1986
# 14143                1        1986
# 14152                1        1986
# 14155                2        1986
# 14158                1        1986
# 15985                1        1990
# 15997                2        1990
# 16010                0        1990
# 16024                1        1990
# 16031                0        1990
# 16034                0        1990
# 16038                1        1990
# 18239                4        1994
# 18249                1        1994
# 18264                2        1994
# 18270                1        1994
# 21135                1        1998
# 21152                5        1998
# 21172                1        1998
# 21187                0        1998
# 21193                1        1998
# 24532                1        2002
# 24550                1        2002
# 24571                0        2002
# 28023                1        2006
# 28041                6        2006
# 28059                0        2006
# 28069                1        2006
# 28083                0        2006
# 31668                1        2010
# 31683                3        2010
# 31705                2        2010
# 31723                2        2010
# 31733                4        2010
# 35534                1        2014
# 35553                1        2014
# 35573                1        2014
# 35585                1        2014
# 35590                1        2014
# 35594                0        2014
# 35598                1        2014

# %% [markdown]
# How many games did Argentina play in World Cup 1986? 7 (straight to the final and won)

# %%
argentina_1930_world_cup.groupby('match_year').count()
# Out:
#             date  home_team  away_team  home_score  away_score  tournament  \
# match_year
# 1930           5          5          5           5           5           5
# 1934           1          1          1           1           1           1
# 1958           3          3          3           3           3           3
# 1962           3          3          3           3           3           3
# 1966           4          4          4           4           4           4
# 1974           6          6          6           6           6           6
# 1978           7          7          7           7           7           7
# 1982           5          5          5           5           5           5
# 1986           7          7          7           7           7           7
# 1990           7          7          7           7           7           7
# 1994           4          4          4           4           4           4
# 1998           5          5          5           5           5           5
# 2002           3          3          3           3           3           3
# 2006           5          5          5           5           5           5
# 2010           5          5          5           5           5           5
# 2014           7          7          7           7           7           7
#
#             city  country  winning_team  goal_difference
# match_year
# 1930           5        5             5                5
# 1934           1        1             1                1
# 1958           3        3             3                3
# 1962           3        3             3                3
# 1966           4        4             4                4
# 1974           6        6             6                6
# 1978           7        7             7                7
# 1982           5        5             5                5
# 1986           7        7             7                7
# 1990           7        7             7                7
# 1994           4        4             4                4
# 1998           5        5             5                5
# 2002           3        3             3                3
# 2006           5        5             5                5
# 2010           5        5             5                5
# 2014           7        7             7                7

# %% [markdown]
# # Analyze
# Win rate (based on historical matches) should be usefule in our analysis and in predicting the outcomes of matches in the World Cup tournament. Other than that, results from direct matches against each other would play certain role as well.
#
# As mentioned above, we are going to drop unimportant columns, such as 'city', 'country'. And we also exclude "Friendly" matches from 'tournament' column in our historical data.
#
# # To be continued!
